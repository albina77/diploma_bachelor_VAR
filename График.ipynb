# %%
import pandas as pd

# %%
file = "/Users/Albina/Documents/Studying/НИР/Отчеты/01.01.2022.xls"

# %%
xl = pd.read_excel(file, sheet_name="2")

# %%
xl.head()
# Out:
#                  Unnamed: 0  Unnamed: 1  \
# 0        2. Расходы бюджета         NaN
# 1   Наименование показателя  Код строки
# 2                       NaN         NaN
# 3                         1           2
# 4   Расходы бюджета - ИТОГО         200
#
#                                  Unnamed: 2                 Unnamed: 3  \
# 0                                       NaN                        NaN
# 1  Код по бюджетной классификации \n(Р, Пр)  Центральное правительство
# 2                                       NaN                  исполнено
# 3                                         3                          4
# 4                                         Х      33 935 256 532 420,64
#
#               Unnamed: 4                                         Unnamed: 5  \
# 0                    NaN                                                NaN
# 1  консолидируемые суммы                                 Федеральный бюджет
# ...

# %%
for i, row in xl.iterrows():
    if row[0] == "Расходы бюджета - ИТОГО":
        print(f"Index: {i}")
        print(f"{row[3]}\n")
# Out:
# Index: 4
# 33 935 256 532 420,64

# %% [markdown]
# Отчеты 1 типа 01.10.2003 - 01.01.2005

# %%
g_keys
# Out:
# dict_keys(['Дата', 'ЦЕЛЕВЫЕ БЮДЖЕТНЫЕ ФОНДЫ ', 'ПРОЧИЕ РАСХОДЫ', 'ДОРОЖНОЕ ХОЗЯЙСТВО', 'ВОЕННАЯ РЕФОРМА', 'ИССЛЕДОВАНИЕ И ИСПОЛЬЗОВАНИЕ КОСМИЧЕСКОГО ПРОСТРАНСТВА', 'МОБИЛИЗАЦИОННАЯ ПОДГОТОВКА ЭКОНОМИКИ', 'УТИЛИЗАЦИЯ И ЛИКВИДАЦИЯ ВООРУЖЕНИЙ, ВКЛЮЧАЯ ВЫПОЛНЕНИЕ МЕЖДУНАРОДНЫХ ДОГОВОРОВ', 'ФИНАНСОВАЯ ПОМОЩЬ ДРУГИМ БЮДЖЕТАМ БЮДЖЕТНОЙ СИСТЕМЫ', 'ПОПОЛНЕНИЕ ГОСУДАРСТВЕННЫХ ЗАПАСОВ И РЕЗЕРВОВ', 'ОБСЛУЖИВАНИЕ ГОСУДАРСТВЕННОГО И МУНИЦИПАЛЬНОГО ДОЛГА', 'СОЦИАЛЬНАЯ ПОЛИТИКА', 'ЗДРАВООХРАНЕНИЕ И ФИЗИЧЕСКАЯ КУЛЬТУРА', 'СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ', 'КУЛЬТУРА, ИСКУССТВО И КИНЕМАТОГРАФИЯ', 'ОБРАЗОВАНИЕ', 'ПРЕДУПРЕЖДЕНИЕ И ЛИКВИДАЦИЯ ПОСЛЕДСТВИЙ ЧРЕЗВЫЧАЙНЫХ СИТУАЦИЙ И СТИХИЙНЫХ БЕДСТВИЙ', 'ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО', 'РАЗВИТИЕ РЫНОЧНОЙ ИНФРАСТРУКТУРЫ', 'ТРАНСПОРТ, СВЯЗЬ И ИНФОРМАТИКА', 'ОХРАНА ОКРУЖАЮЩЕЙ ПРИРОДНОЙ СРЕДЫ И ПРИРОДНЫХ РЕСУРСОВ, ГИДРОМЕТЕОРОЛОГИЯ, КАРТОГРАФИЯ И ГЕОДЕЗИЯ', 'СЕЛЬСКОЕ ХОЗЯЙСТВО И РЫБОЛОВСТВО', 'ПРОМЫШЛЕННОСТЬ, ЭНЕРГЕТИКА И СТРОИТЕЛЬСТВО', 'ФУНДАМЕНТАЛЬНЫЕ ИССЛЕДОВАНИ
# ...

# %%
import numpy as np

years = ["01.10.2003", "01.01.2004", "01.04.2004", "01.07.2004", "01.10.2004", "01.01.2005"]
g = {"Дата": years, "ЦЕЛЕВЫЕ БЮДЖЕТНЫЕ ФОНДЫ ": [], "ПРОЧИЕ РАСХОДЫ": [], "ДОРОЖНОЕ ХОЗЯЙСТВО": [], "ВОЕННАЯ РЕФОРМА": [], 
     "ИССЛЕДОВАНИЕ И ИСПОЛЬЗОВАНИЕ КОСМИЧЕСКОГО ПРОСТРАНСТВА": [], "МОБИЛИЗАЦИОННАЯ ПОДГОТОВКА ЭКОНОМИКИ": [],
    "УТИЛИЗАЦИЯ И ЛИКВИДАЦИЯ ВООРУЖЕНИЙ, ВКЛЮЧАЯ ВЫПОЛНЕНИЕ МЕЖДУНАРОДНЫХ ДОГОВОРОВ": [], "ФИНАНСОВАЯ ПОМОЩЬ ДРУГИМ БЮДЖЕТАМ БЮДЖЕТНОЙ СИСТЕМЫ": [],
    "ПОПОЛНЕНИЕ ГОСУДАРСТВЕННЫХ ЗАПАСОВ И РЕЗЕРВОВ": [], "ОБСЛУЖИВАНИЕ ГОСУДАРСТВЕННОГО И МУНИЦИПАЛЬНОГО ДОЛГА": [],
    "СОЦИАЛЬНАЯ ПОЛИТИКА": [], "ЗДРАВООХРАНЕНИЕ И ФИЗИЧЕСКАЯ КУЛЬТУРА": [], "СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ": [],
    "КУЛЬТУРА, ИСКУССТВО И КИНЕМАТОГРАФИЯ": [], "ОБРАЗОВАНИЕ": [], "ПРЕДУПРЕЖДЕНИЕ И ЛИКВИДАЦИЯ ПОСЛЕДСТВИЙ ЧРЕЗВЫЧАЙНЫХ СИТУАЦИЙ И СТИХИЙНЫХ БЕДСТВИЙ": [],
    "ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО": [], "РАЗВИТИЕ РЫНОЧНОЙ ИНФРАСТРУКТУРЫ": [], "ТРАНСПОРТ, СВЯЗЬ И ИНФОРМАТИКА": [],
    "ОХРАНА ОКРУЖАЮЩЕЙ ПРИРОДНОЙ СРЕДЫ И ПРИРОДНЫХ РЕСУРСОВ, ГИДРОМЕТЕОРОЛОГИЯ, КАРТОГРАФИЯ И ГЕОДЕЗИЯ": [],
    "СЕЛЬСКОЕ ХОЗЯЙСТВО И РЫБОЛОВСТВО": [], "ПРОМЫШЛЕННОСТЬ, ЭНЕРГЕТИКА И СТРОИТЕЛЬСТВО": [], "ФУНДАМЕНТАЛЬНЫЕ ИССЛЕДОВАНИЯ И СОДЕЙСТВИЕ НАУЧНО-ТЕХНИЧЕСКОМУ ПРОГРЕССУ": [],
    "ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ И ОБЕСПЕЧЕНИЕ БЕЗОПАСНОСТИ ГОСУДАРСТВА": [], "НАЦИОНАЛЬНАЯ ОБОРОНА": [],
    "МЕЖДУНАРОДНАЯ ДЕЯТЕЛЬНОСТЬ": [], "СУДЕБНАЯ ВЛАСТЬ": [], "ГОСУДАРСТВЕННОЕ   УПРАВЛЕНИЕ  И МЕСТНОЕ САМОУПРАВЛЕНИЕ": []}
g_keys = g.keys()
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="Лист1")
    for l, row in xl.iterrows():
        if row[1] in g_keys:
            #print(f"Index: {l}")
            print(row[1])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[1]] = row[2]
    k += 1
print(df_to_excel)
# Out:
# ГОСУДАРСТВЕННОЕ   УПРАВЛЕНИЕ  И МЕСТНОЕ САМОУПРАВЛЕНИЕ
# 122273424
#
# СУДЕБНАЯ ВЛАСТЬ
# 17546615
#
# МЕЖДУНАРОДНАЯ ДЕЯТЕЛЬНОСТЬ
# 14958368
#
# НАЦИОНАЛЬНАЯ ОБОРОНА
# 242931842
#
# ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ И ОБЕСПЕЧЕНИЕ БЕЗОПАСНОСТИ ГОСУДАРСТВА
# 200771043
#
# ФУНДАМЕНТАЛЬНЫЕ ИССЛЕДОВАНИЯ И СОДЕЙСТВИЕ НАУЧНО-ТЕХНИЧЕСКОМУ ПРОГРЕССУ
# 28534025
#
# ПРОМЫШЛЕННОСТЬ, ЭНЕРГЕТИКА И СТРОИТЕЛЬСТВО
# 208648242
#
# СЕЛЬСКОЕ ХОЗЯЙСТВО И РЫБОЛОВСТВО
# 43954118
#
# ОХРАНА ОКРУЖАЮЩЕЙ ПРИРОДНОЙ СРЕДЫ И ПРИРОДНЫХ РЕСУРСОВ, ГИДРОМЕТЕОРОЛОГИЯ, КАРТОГРАФИЯ И ГЕОДЕЗИЯ
# 12035848
#
# ТРАНСПОРТ, СВЯЗЬ И ИНФОРМАТИКА
# 28232754
#
# РАЗВИТИЕ РЫНОЧНОЙ ИНФРАСТРУКТУРЫ
# 1208766
#
# ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО
# 177785521
#
# ПРЕДУПРЕЖДЕНИЕ И ЛИКВИДАЦИЯ ПОСЛЕДСТВИЙ ЧРЕЗВЫЧАЙНЫХ СИТУАЦИЙ И СТИХИЙНЫХ БЕДСТВИЙ
# 28679421
#
# ОБРАЗОВАНИЕ
# 318106920
#
# КУЛЬТУРА, ИСКУССТВО И КИНЕМАТОГРАФИЯ
# 39669796
#
# СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ
# 15833029
#
# ЗДРАВООХРАНЕНИЕ И ФИЗИЧЕСКАЯ КУЛЬТУРА
# 202565863
#
# ...

# %%
writer = pd.ExcelWriter('g_by_categories.xlsx')
df_to_excel.to_excel(writer) # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 2 типа 01.04.2005 - 01.01.2006

# %%
years = ["2005.04.01", "2005.07.01", "2005.10.01", "2006.01.01"]
g = {"Дата": years, "ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ": [], "НАЦИОНАЛЬНАЯ ОБОРОНА": [], "НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ": [],
     "НАЦИОНАЛЬНАЯ ЭКОНОМИКА": [], "ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО": [], "ОХРАНА ОКРУЖАЮЩЕЙ СРЕДЫ": [],
     "ОБРАЗОВАНИЕ": [], "КУЛЬТУРА, КИНЕМАТОГРАФИЯ И СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ": [], 
     "ЗДРАВООХРАНЕНИЕ И СПОРТ": [], "СОЦИАЛЬНАЯ ПОЛИТИКА": [], "МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ": []}
g_keys = g.keys()
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="Лист1")
    for l, row in xl.iterrows():
        if row[1] in g_keys:
            #print(f"Index: {l}")
            print(row[1])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[1]] = row[2]
    k += 1
print(df_to_excel)
# Out:
# ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ
# 153585978
#
# НАЦИОНАЛЬНАЯ ОБОРОНА
# 117339181
#
# НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ
# 104953849
#
# НАЦИОНАЛЬНАЯ ЭКОНОМИКА
# 107598317
#
# ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО
# 71371954
#
# ОХРАНА ОКРУЖАЮЩЕЙ СРЕДЫ
# 2443614
#
# ОБРАЗОВАНИЕ
# 139401663
#
# КУЛЬТУРА, КИНЕМАТОГРАФИЯ И СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ
# 24533787
#
# ЗДРАВООХРАНЕНИЕ И СПОРТ
# 94867008
#
# СОЦИАЛЬНАЯ ПОЛИТИКА
# 96805294
#
# МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ
# 147967689
#
# ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ
# 318034177
#
# НАЦИОНАЛЬНАЯ ОБОРОНА
# 244914882
#
# НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ
# 239333240
#
# НАЦИОНАЛЬНАЯ ЭКОНОМИКА
# 271044989
#
# ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО
# 175353701
#
# ОХРАНА ОКРУЖАЮЩЕЙ СРЕДЫ
# 6952140
#
# ОБРАЗОВАНИЕ
# 361170625
#
# КУЛЬТУРА, КИНЕМАТОГРАФИЯ И СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ
# 61908581
#
# ЗДРАВООХРАНЕНИЕ И СПОРТ
# 223374796
#
# СОЦИАЛЬНАЯ ПОЛИТИКА
# 219834139
#
# МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ
# 321122970
#
# ...

# %%
g_keys
# Out:
# dict_keys(['Дата', 'ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ', 'НАЦИОНАЛЬНАЯ ОБОРОНА', 'НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ', 'НАЦИОНАЛЬНАЯ ЭКОНОМИКА', 'ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО', 'ОХРАНА ОКРУЖАЮЩЕЙ СРЕДЫ', 'ОБРАЗОВАНИЕ', 'КУЛЬТУРА, КИНЕМАТОГРАФИЯ И СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ', 'ЗДРАВООХРАНЕНИЕ И СПОРТ', 'СОЦИАЛЬНАЯ ПОЛИТИКА', 'МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ'])

# %%
writer = pd.ExcelWriter('g_by_categories2.xlsx')
df_to_excel.to_excel(writer) # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 3 типа 01.04.2006

# %%
years = ["2006.04.01"]
g_keys = ['Дата',
 'Общегосударственные вопросы',
 'Национальная оборона',
 'Национальная безопасность и правоохранительная деятельность',
 'Национальная экономика',
 'Жилищно-коммунальное хозяйство',
 'Охрана окружающей среды',
 'Образование',
 'Культура, кинематография и средства массовой информации',
 'Здравоохранение и спорт',
 'Социальная политика',
 'Межбюджетные трансферты']
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="отчет с формулами")
    for l, row in xl.iterrows():
        if row[1] in g_keys:
            #print(f"Index: {l}")
            print(row[1])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[1]] = row[2]
    k += 1
print(df_to_excel)
# Out:
# Общегосударственные вопросы
# 159538781362.26
#
# Национальная оборона
# 139493359282.06
#
# Национальная безопасность и правоохранительная деятельность
# 137948344662.32
#
# Национальная экономика
# 111207902143.05002
#
# Жилищно-коммунальное хозяйство
# 77579523089.74
#
# Охрана окружающей среды
# 2901243505.87
#
# Образование
# 167035565434.80002
#
# Культура, кинематография и средства массовой информации
# 27265459847.9
#
# Здравоохранение и спорт
# 119107533981.35
#
# Социальная политика
# 117238341075.49
#
# Межбюджетные трансферты
# 214904857944
#
#          Дата  Общегосударственные вопросы  Национальная оборона  \
# 0  2006.04.01                 1.595388e+11          1.394934e+11
#
#    Национальная безопасность и правоохранительная деятельность  \
# 0                                       1.379483e+11
#
#    Национальная экономика  Жилищно-коммунальное хозяйство  \
# 0            1.112079e+11                    7.757952e+10
#
#    Охрана окружающей среды   Образование  \
# ...

# %%
writer = pd.ExcelWriter('g_by_categories3.xlsx')
df_to_excel.to_excel(writer) # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 4 типа 01.07.2006

# %%
years = ["2006.07.01"]
g_keys = ['Дата',
 'Общегосударственные вопросы',
 'Национальная оборона',
 'Национальная безопасность и правоохранительная деятельность',
 'Национальная экономика',
 'Жилищно-коммунальное хозяйство',
 'Охрана окружающей среды',
 'Образование',
 'Культура, кинематография и средства массовой информации',
 'Здравоохранение и спорт',
 'Социальная политика',
 'Межбюджетные трансферты']
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="расходы")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            #print(f"Index: {l}")
            print(row[0])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[0]] = row[2]
    k += 1
print(df_to_excel)
# Out:
# Общегосударственные вопросы
# 643589395200
#
# Национальная оборона
# 656709280000
#
# Национальная безопасность и правоохранительная деятельность
# 538942905300
#
# Национальная экономика
# 344218524000
#
# Жилищно-коммунальное хозяйство
# 53701811800
#
# Охрана окружающей среды
# 6334289100
#
# Образование
# 200852539400
#
# Культура, кинематография и средства массовой информации
# 51346107500
#
# Здравоохранение и спорт
# 153323941600
#
# Социальная политика
# 217748049500
#
# Межбюджетные трансферты
# 1436050545400
#
#          Дата  Общегосударственные вопросы  Национальная оборона  \
# 0  2006.07.01                 643589395200          656709280000
#
#    Национальная безопасность и правоохранительная деятельность  \
# 0                                       538942905300
#
#    Национальная экономика  Жилищно-коммунальное хозяйство  \
# 0            344218524000                     53701811800
#
#    Охрана окружающей среды   Образование  \
# ...

# %%
writer = pd.ExcelWriter('g_by_categories3.xlsx')
df_to_excel.to_excel(writer, startrow=2) # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 5 типа 01.10.2006

# %%
years = ["2006.10.01"]
g_keys = ['Дата',
 'Общегосударственные вопросы',
 'Национальная оборона',
 'Национальная безопасность и правоохранительная деятельность',
 'Национальная экономика',
 'Жилищно-коммунальное хозяйство',
 'Охрана окружающей среды',
 'Образование',
 'Культура, кинематография и средства массовой информации',
 'Здравоохранение и спорт',
 'Социальная политика',
 'Межбюджетные трансферты']
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="4")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            #print(f"Index: {l}")
            print(row[0])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[0]] = row[2]
    k += 1
print(df_to_excel)
# Out:
# Общегосударственные вопросы
# 561638808785.82
#
# Национальная оборона
# 447228996342.05
#
# Национальная безопасность и правоохранительная деятельность
# 474421969910.73
#
# Национальная экономика
# 553701715653.99
#
# Жилищно-коммунальное хозяйство
# 363828041837.8
#
# Охрана окружающей среды
# 13577019515.69
#
# Образование
# 664546270565.63
#
# Культура, кинематография и средства массовой информации
# 116114216947.25
#
# Здравоохранение и спорт
# 706280203186.48
#
# Социальная политика
# 1579776107309.31
#
# Межбюджетные трансферты
# 39044674.3
#
#          Дата  Общегосударственные вопросы  Национальная оборона  \
# 0  2006.10.01                 5.616388e+11          4.472290e+11
#
#    Национальная безопасность и правоохранительная деятельность  \
# 0                                       4.744220e+11
#
#    Национальная экономика  Жилищно-коммунальное хозяйство  \
# 0            5.537017e+11                    3.638280e+11
#
#    Охрана окружающей среды   Образование  \
# ...

# %%
writer = pd.ExcelWriter('g_by_categories3.xlsx')
df_to_excel.to_excel(writer, sheet_name="2006.10.01") # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 6 типа 01.01.2007 - 01.01.2008

# %%
years = []
for i in range(2007, 2018):
    for j in ["01", "04", "07", "10"]:
        years.append(str(i)+"."+j+".01")
years
# Out:
# ['2007.01.01',
#  '2007.04.01',
#  '2007.07.01',
#  '2007.10.01',
#  '2008.01.01',
#  '2008.04.01',
#  '2008.07.01',
#  '2008.10.01',
#  '2009.01.01',
#  '2009.04.01',
#  '2009.07.01',
#  '2009.10.01',
#  '2010.01.01',
#  '2010.04.01',
#  '2010.07.01',
#  '2010.10.01',
#  '2011.01.01',
#  '2011.04.01',
#  '2011.07.01',
#  '2011.10.01',
#  '2012.01.01',
#  '2012.04.01',
#  '2012.07.01',
#  '2012.10.01',
#  '2013.01.01',
#  '2013.04.01',
#  '2013.07.01',
#  '2013.10.01',
#  '2014.01.01',
#  '2014.04.01',
#  '2014.07.01',
#  '2014.10.01',
#  '2015.01.01',
#  '2015.04.01',
#  '2015.07.01',
#  '2015.10.01',
#  '2016.01.01',
#  '2016.04.01',
#  '2016.07.01',
#  '2016.10.01',
#  '2017.01.01',
#  '2017.04.01',
#  '2017.07.01',
#  '2017.10.01']

# %%
years = ['2007.01.01',
 '2007.04.01',
 '2007.07.01',
 '2007.10.01',
 '2008.01.01']
g_keys = ['Дата',
 'Общегосударственные вопросы',
 'Национальная оборона',
 'Национальная безопасность и правоохранительная деятельность',
 'Национальная экономика',
 'Жилищно-коммунальное хозяйство',
 'Охрана окружающей среды',
 'Образование',
 'Культура, кинематография и средства массовой информации',
 'Здравоохранение и спорт',
 'Социальная политика',
 'Межбюджетные трансферты']
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="2")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            #print(f"Index: {l}")
            print(row[0])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[0]] = row[2]
    k += 1
print(df_to_excel)
# Out:
# Общегосударственные вопросы
# 824279219757.85
#
# Национальная оборона
# 683336546668.96
#
# Национальная безопасность и правоохранительная деятельность
# 714337123456
#
# Национальная экономика
# 949541151979.23
#
# Жилищно-коммунальное хозяйство
# 631416125817.46
#
# Охрана окружающей среды
# 23166706705.05
#
# Образование
# 1033283004704.85
#
# Культура, кинематография и средства массовой информации
# 188691888592.42
#
# Здравоохранение и спорт
# 1074660114235.71
#
# Социальная политика
# 2258235895691.95
#
# Межбюджетные трансферты
# 3061345817.63
#
# Общегосударственные вопросы
# 171694989445.8
#
# Национальная оборона
# 148318797216.23
#
# Национальная безопасность и правоохранительная деятельность
# 159002214917.2
#
# Национальная экономика
# 167161774121.1
#
# Жилищно-коммунальное хозяйство
# 92133394120.85
#
# Охрана окружающей среды
# 3151553273.03
#
# Образование
# 206573109675.92
#
# Культура, кинематография и средства массовой информации
# 35184904194.03
#
# ...

# %%
writer = pd.ExcelWriter('g_by_categories4.xlsx')
df_to_excel.to_excel(writer, sheet_name="2006.10.01") # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 7 типа 01.04.2008 - 01.10.2017

# %%
years = []
for i in range(2008, 2018):
    for j in ["01", "04", "07", "10"]:
        years.append(str(i)+"."+j+".01")
years[1:]
years1 = years[4:]
years2 = years[2:4]
years2
# Out:
# ['2008.07.01', '2008.10.01']

# %%
g_keys = ['Дата', 'ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ', 'НАЦИОНАЛЬНАЯ ОБОРОНА', 
          'НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ', 'НАЦИОНАЛЬНАЯ ЭКОНОМИКА', 
          'ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО', 'ОХРАНА ОКРУЖАЮЩЕЙ СРЕДЫ', 'ОБРАЗОВАНИЕ', 
          'КУЛЬТУРА, КИНЕМАТОГРАФИЯ, СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ', 'ЗДРАВООХРАНЕНИЕ, ФИЗИЧЕСКАЯ КУЛЬТУРА И СПОРТ', 
          'СОЦИАЛЬНАЯ ПОЛИТИКА', 'МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ', 'ЗДРАВООХРАНЕНИЕ', 'КУЛЬТУРА, КИНЕМАТОГРАФИЯ', 
          'ФИЗИЧЕСКАЯ КУЛЬТУРА И СПОРТ', 'СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ', 
          'МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ ОБЩЕГО ХАРАКТЕРА БЮДЖЕТАМ СУБЪЕКТОВ РОССИЙСКОЙ ФЕДЕРАЦИИ И МУНИЦИПАЛЬНЫХ ОБРАЗОВАНИЙ']
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years[1:]
df_to_excel = pd.DataFrame(g)
k = 0

for i in years2:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="2")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            print(i)
            print(row[0])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[0]] = row[2]
    k += 1

for i in years1:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="2")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            print(i)
            print(row[0])
            print(f"{row[3]}\n")
            df_to_excel.at[k, row[0]] = row[3]
    k += 1
print(df_to_excel)
# Out:
#           Дата  Общегосударственные вопросы  Национальная оборона  \
# 0   2018.04.01                            6                     6
# 1   2018.07.01                            6                     6
# 2   2018.10.01                            6                     6
# 3   2019.01.01                            6                     6
# 4   2019.04.01                            6                     6
# 5   2019.07.01                            6                     6
# 6   2019.10.01                            6                     6
# 7   2020.01.01                            6                     6
# 8   2020.04.01                            6                     6
# 9   2020.07.01                            6                     6
# 10  2020.10.01                            6                     6
# 11  2022.01.01                            6                     6
#
#     Национальная безопасность и правоохранительная деятельность  \
# ...

# %%
writer = pd.ExcelWriter('g_by_categories5.xlsx')
df_to_excel.to_excel(writer) # save the excel writer.save()
writer.save()

# %% [markdown]
# Отчеты 8 типа 01.01.2018 - 01.01.2022

# %%
years = []
for i in range(2018, 2022):
    for j in ["01", "04", "07", "10"]:
        years.append(str(i)+"."+j+".01")
years.append("2022.01.01")
years
# Out:
# ['2018.01.01',
#  '2018.04.01',
#  '2018.07.01',
#  '2018.10.01',
#  '2019.01.01',
#  '2019.04.01',
#  '2019.07.01',
#  '2019.10.01',
#  '2020.01.01',
#  '2020.04.01',
#  '2020.07.01',
#  '2020.10.01',
#  '2021.01.01',
#  '2021.04.01',
#  '2021.07.01',
#  '2021.10.01',
#  '2022.01.01']

# %%
g_keys = ['Дата',
 'Общегосударственные вопросы',
 'Национальная оборона',
 'Национальная безопасность и правоохранительная деятельность',
 'Национальная экономика',
 'Жилищно-коммунальное хозяйство',
 'Охрана окружающей среды',
 'Образование',
 'Культура, кинематография',
          'Средства массовой информации',
 'Здравоохранение',
          'Физическая культура и спорт',
 'Социальная политика',
 'Межбюджетные трансферты']
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years[1:]
df_to_excel = pd.DataFrame(g)
k = 0

for i in years:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name=1)
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            print(i)
            print(row[0])
            print(f"{row[3]}\n")
            df_to_excel.at[k, row[0]] = row[3]
    k += 1
print(df_to_excel)
# Out:
# 2018.01.01
# Общегосударственные вопросы
# 1952607242773.75
#
# 2018.01.01
# Национальная оборона
# 2854205591510.69
#
# 2018.01.01
# Национальная безопасность и правоохранительная деятельность
# 2034122739588.52
#
# 2018.01.01
# Национальная экономика
# 4332042258154.92
#
# 2018.01.01
# Жилищно-коммунальное хозяйство
# 1209898801691.35
#
# 2018.01.01
# Охрана окружающей среды
# 116282200794.95
#
# 2018.01.01
# Образование
# 3264158990318.64
#
# 2018.01.01
# Культура, кинематография
# 492904581687.34
#
# 2018.01.01
# Здравоохранение
# 2820953408097.94
#
# 2018.01.01
# Социальная политика
# 11 615 913 404 389,54
#
# 2018.01.01
# Физическая культура и спорт
# 327016420358.15
#
# 2018.01.01
# Средства массовой информации
# 127271887357.81
#
# 2018.04.01
# Общегосударственные вопросы
# 400625759365.12
#
# 2018.04.01
# Национальная оборона
# 756427323721.35
#
# 2018.04.01
# Национальная безопасность и правоохранительная деятельность
# 417768856623.12
#
# 2018.04.01
# ...

# %%
writer = pd.ExcelWriter('g_by_categories6.xlsx')
df_to_excel.to_excel(writer) # save the excel writer.save()
writer.save()

# %% [markdown]
# Часть 2
# Вычисление данных не накопленным итогом, а за квартал

# %%
xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/calculations/g_by_categories2.xlsx")
xl
# Out:
#          Дата  ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ  НАЦИОНАЛЬНАЯ ОБОРОНА  \
# 0  2005-04-01                 1.535860e+08          1.173392e+08
# 1  2005-07-01                 3.180342e+08          2.449149e+08
# 2  2005-10-01                 5.313049e+08          3.729447e+08
# 3  2006-01-01                 7.513998e+11          5.817636e+11
# 4  2006-04-01                 1.595388e+11          1.394934e+11
# ..        ...                          ...                   ...
# 68        NaT                          NaN                   NaN
# 69        NaT                 2.200949e+11          2.088189e+11
# 70        NaT                 1.822757e+11                   NaN
# 71        NaT                          NaN                   NaN
# 72        NaT                 2.200949e+11          2.088189e+11
#
#     НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ  \
# 0                                        1.049538e+08
# 1                                        2.393332e+08
# ...

# %%
xl2 = xl.copy()

for l, row in xl.iterrows():
    if row['Дата'].year >= 2018:
        print(row['Дата'].quarter)
        if row['Дата'].quarter != 2:
            for key, value in row.items():
                if key != "Дата":
                    print(value)
                    print(prev_row[key])
                    xl2.at[l, key] = value - prev_row[key]
        prev_row = row

# for i in range(3):
#     for column in xl2:
#         if column != 'Дата':
#             xl2.at[i, column] = xl2[i, column] * 1000
xl2[50:]
writer = pd.ExcelWriter('g_by_categories_2018_2021.xlsx')
xl2.to_excel(writer) # save the excel writer.save()
writer.save()
xl2[50:]
# Out:
# 1
# 1952607242773.75
# 2851885089412.82
# 2854205591510.69
# 3574975265122.5
# 2034122739588.52
# 2504465686235.95
# 4332042258154.92
# 7224732434182.04
# 1209898801691.35
# 2171994683911.43
# 116282200794.95
# 438396920673.7
# 3264158990318.64
# 4690655194494.63
# 620176469045.15
# 823247433269.1901
# 3147969828456.09
# 5604866075888.67
# 11615913404389.5
# 16002264799812.2
# 179500.0
# 9221484.3
# 2
# 3
# 896414395512.98
# 400625759365.12
# 1434842513524.28
# 756427323721.35
# 904510045741.57
# 417768856623.12
# 1522789474118.88
# 615794531642.7
# 447481229572.62
# 199608633161.27
# 79909456745.21
# 35002972711.9
# 1863974787607.3
# 771687018100.65
# 295744657459.68
# 130947238008.03
# 1598778142587.26
# 697220924922.7999
# 5769701419041.84
# 2830483054199.14
# 6.0
# 6.0
# 4
# 1389088776132.51
# 896414395512.98
# 1930162713107.17
# 1434842513524.28
# 1388841428423.96
# 904510045741.57
# 2571031351709.35
# 1522789474118.88
# 733143667528.0
# 447481229572.62
# 107929356924.04
# ...

# %%
writer = pd.ExcelWriter('g_by_categories_subtracted.xlsx')
xl2.to_excel(writer) # save the excel writer.save()
writer.save()

# %%
g_keys = {'ОБЩЕГОСУДАРСТВЕННЫЕ ВОПРОСЫ': , 'НАЦИОНАЛЬНАЯ ОБОРОНА', 
          'НАЦИОНАЛЬНАЯ БЕЗОПАСНОСТЬ И ПРАВООХРАНИТЕЛЬНАЯ ДЕЯТЕЛЬНОСТЬ', 'НАЦИОНАЛЬНАЯ ЭКОНОМИКА', 
          'ЖИЛИЩНО-КОММУНАЛЬНОЕ ХОЗЯЙСТВО', 'ОХРАНА ОКРУЖАЮЩЕЙ СРЕДЫ', 'ОБРАЗОВАНИЕ', 
          'КУЛЬТУРА, КИНЕМАТОГРАФИЯ, СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ', 'ЗДРАВООХРАНЕНИЕ, ФИЗИЧЕСКАЯ КУЛЬТУРА И СПОРТ', 
          'СОЦИАЛЬНАЯ ПОЛИТИКА', 'МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ', 'ЗДРАВООХРАНЕНИЕ', 'КУЛЬТУРА, КИНЕМАТОГРАФИЯ', 
          'ФИЗИЧЕСКАЯ КУЛЬТУРА И СПОРТ', 'СРЕДСТВА МАССОВОЙ ИНФОРМАЦИИ', 
          'МЕЖБЮДЖЕТНЫЕ ТРАНСФЕРТЫ ОБЩЕГО ХАРАКТЕРА БЮДЖЕТАМ СУБЪЕКТОВ РОССИЙСКОЙ ФЕДЕРАЦИИ И МУНИЦИПАЛЬНЫХ ОБРАЗОВАНИЙ'}
g = {i: [] for i in g_keys}
for i in g_keys:
    g[i] = np.array(6)
g["Дата"] = years[1:]
df_to_excel = pd.DataFrame(g)
k = 0

for i in years2:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="2")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            print(i)
            print(row[0])
            print(f"{row[2]}\n")
            df_to_excel.at[k, row[0]] = row[2]
    k += 1

for i in years1:
    xl = pd.read_excel("/Users/Albina/Documents/Studying/НИР/Отчеты/" + i + ".xls", sheet_name="2")
    for l, row in xl.iterrows():
        if row[0] in g_keys:
            print(i)
            print(row[0])
            print(f"{row[3]}\n")
            df_to_excel.at[k, row[0]] = row[3]
    k += 1
print(df_to_excel)

# %%
import matplotlib.pyplot as plt
import pandas as pd

arr = []
xl = None

xlxs = pd.read_excel("/Users/Albina/Documents/Studying/НИР/calculations/g_by_categories_subtracted.xlsx", sheet_name='deflator_plot_p')
# for l, row in xl.iterrows():
#     arr_local = []
#     for i in row:
#         arr_local.append(i)
#     arr.append(arr_local)
#print(arr)
xlxs[0:17]
#df = pd.DataFrame(arr, columns = list(xl.columns))
_, ax = plt.subplots(figsize=(13, 12))
xlxs[0:17].plot(x='Дата', kind='bar', stacked=True, ax=ax)
ax.legend(loc='upper left')
ax.set_ylabel('Расходы, млрд.руб.', size=12)
ax.set_xlabel('Год', size=12)
plt.show()

# %%
xl[0:17]['Дата'] = pd.array([int(i) for i in xl[0:17]['Дата']])
# Out:
# /var/folders/cf/xw2wzwf95hl4b23f43_p1khc0000gp/T/ipykernel_84896/3913793144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xl[0:17]['Дата'] = pd.array([int(i) for i in xl[0:17]['Дата']])

# %%
import matplotlib.pyplot as plt
import pandas as pd

arr = []
xl = None

xlxs = pd.read_excel("/Users/Albina/Documents/Studying/НИР/calculations/g_by_categories_subtracted.xlsx", sheet_name='deflator_plot_not_p')
# for l, row in xl.iterrows():
#     arr_local = []
#     for i in row:
#         arr_local.append(i)
#     arr.append(arr_local)
#print(arr)
xlxs[0:17]
#df = pd.DataFrame(arr, columns = list(xl.columns))
_, ax = plt.subplots(figsize=(13, 12))
xlxs[0:17].plot(x='Дата', kind='bar', stacked=True, ax=ax)
ax.legend(loc='upper left')
ax.set_ylabel('Расходы, млрд.руб.', size=12)
ax.set_xlabel('Год', size=12)
plt.show()
